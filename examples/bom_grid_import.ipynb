# %%
# %pylab inline

import bomber
import rasterio
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bomber.__version__
# Out:
# '0.0.1.dev1'

# %%
bomber.grid_to_geotiff('latest.grid')

# %%
with rasterio.drivers():
    with rasterio.open('latest.grid.geotiff') as src:
        imshow(src.read(1))
