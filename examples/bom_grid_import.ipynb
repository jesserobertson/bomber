# %%
# %pylab inline

from bomber import grid_to_geotiff
import rasterio

# %%
grid_to_geotiff('latest.grid')

# %%
with rasterio.drivers():
    with rasterio.open('latest.grid.geotiff') as src:
        imshow(src.read(1))
